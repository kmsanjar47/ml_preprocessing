# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
x =  df.drop('Profit', axis=1)

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport     Area
# 0        114523.61       136897.80  471784.10    Dhaka
# 1        162597.70       151377.59  443898.53      Ctg
# 2        153441.51       101145.55  407934.54  Rangpur
# 3        144372.41       118671.85  383199.62    Dhaka
# 4        142107.34        91391.77  366168.42  Rangpur

# %% [markdown]
# # Measure of Central Tendency

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df[19:20]
# Out:
#     Marketing Spend  Administration  Transport   Area     Profit
# 19          86419.7       153514.11        NaN  Dhaka  122776.86

# %%
df.Transport.mean() #not for outlier
# Out:
# 215331.7324489796

# %%
df.Transport.median() #for outliers
# Out:
# 214634.81

# %%
df.Transport.max()
# Out:
# 471784.1

# %%
df.Transport.min()
# Out:
# 0.0

# %%
df.Transport = df.Transport.fillna(df.Transport.mean())

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df[19:20]
# Out:
#     Marketing Spend  Administration      Transport   Area     Profit
# 19          86419.7       153514.11  215331.732449  Dhaka  122776.86

# %% [markdown]
# # Label Encoder

# %%
def label_encoder(df, col):
    label_map = {}
    encoded_value = []

    for instance in df[col]:
        if instance not in label_map:
            label_map[instance] = len(label_map)
        encoded_value.append(label_map[instance])
    return encoded_value, label_map

encoded_value, label_map = label_encoder(x, 'Area')
x.Area = encoded_value

# %%
x.head()
# Out:
#    Marketing Spend  Administration  Transport  Area
# 0        114523.61       136897.80  471784.10     0
# 1        162597.70       151377.59  443898.53     1
# 2        153441.51       101145.55  407934.54     2
# 3        144372.41       118671.85  383199.62     0
# 4        142107.34        91391.77  366168.42     2

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1 = df.copy()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1.Area = le.fit_transform(df[['Area']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # Using For Loop

# %%
#assignment

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
le = LabelEncoder()

for col_name in df.columns:
    col_data = df[col_name]
    if col_data.dtype == "object":
        col_data = le.fit_transform(col_data)

df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # One Hot Encoder

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
pd.get_dummies(df, prefix='area', drop_first=True).head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %%
#For Loop

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
for col_name in df.columns:
    col_data = df[col_name]
    if col_data.dtype == "object":
        df = pd.get_dummies(df, prefix=col_name.lower(), drop_first=True).head()

df.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83        True
# 1        162597.70       151377.59  443898.53  191792.06       False
# 2        153441.51       101145.55  407934.54  191050.39       False
# 3        144372.41       118671.85  383199.62  182901.99        True
# 4        142107.34        91391.77  366168.42  166187.94       False
#
#    area_Rangpur
# 0         False
# 1         False
# 2          True
# 3         False
# 4          True

# %% [markdown]
# # ORDINAL

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal = OrdinalEncoder(categories = [['Dhaka', 'Ctg', 'Rangpur']])

# %%
df.Area = ordinal.fit_transform(df[['Area']])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   0.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   0.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94

# %%
#For Loop

# %%
df = pd.read_csv('supershops.csv')
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# <h1>Preprocessing a DataSet</h1>

# %%
df = pd.read_csv('churn.csv')

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6530
# Churn                  2
# dtype: int64

# %% [markdown]
# <h3>Encoding</h3>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col_name in df.columns:
    if df[col_name].nunique() and df[col_name].dtype == "object" and col_name != "customerID":
        df[col_name] = le.fit_transform(df[col_name])

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# 2             1              0                0               2  ...
# 3             0              1                0               2  ...
# 4             1              0                1               0  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
#Check for NaN
df.isna().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
temp = df.loc[df["TotalCharges"].isna(), "customerID"].to_numpy()

# %%
df[df["TotalCharges"].isna()]
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 488   4472-LVYGI       0              0        1           1       0
# 753   3115-CZMZD       1              0        0           1       0
# 936   5709-LVOEQ       0              0        1           1       0
# 1082  4367-NUYAO       1              0        1           1       0
# 1340  1371-DWPAZ       0              0        1           1       0
# 3331  7644-OMVMY       1              0        1           1       0
# 3826  3213-VVOLG       1              0        1           1       0
# 4380  2520-SGTTA       0              0        1           1       0
# 5218  2923-ARZLG       1              0        1           1       0
# 6670  4075-WKNIU       0              0        1           1       0
# 6754  2775-SEFEE       1              0        0           1       0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
temp
# Out:
# array(['4472-LVYGI', '3115-CZMZD', '5709-LVOEQ', '4367-NUYAO',
#        '1371-DWPAZ', '7644-OMVMY', '3213-VVOLG', '2520-SGTTA',
#        '2923-ARZLG', '4075-WKNIU', '2775-SEFEE'], dtype=object)

# %%
#Assuming there are no outliers
#So we will be using the mean value for filling those gap
df["TotalCharges"] = df.TotalCharges.fillna(df.TotalCharges.mean())

# %%
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df[df["customerID"].isin(temp)]
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 488   4472-LVYGI       0              0        1           1       0
# 753   3115-CZMZD       1              0        0           1       0
# 936   5709-LVOEQ       0              0        1           1       0
# 1082  4367-NUYAO       1              0        1           1       0
# 1340  1371-DWPAZ       0              0        1           1       0
# 3331  7644-OMVMY       1              0        1           1       0
# 3826  3213-VVOLG       1              0        1           1       0
# 4380  2520-SGTTA       0              0        1           1       0
# 5218  2923-ARZLG       1              0        1           1       0
# 6670  4075-WKNIU       0              0        1           1       0
# 6754  2775-SEFEE       1              0        0           1       0
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %% [markdown]
# <h3>Scale The DataFrame</h3>

# %%
#Assuming there is no outliers

# %%
df.dtypes
# Out:
# customerID           object
# gender                int32
# SeniorCitizen         int64
# Partner               int32
# Dependents            int32
# tenure                int64
# PhoneService          int32
# MultipleLines         int32
# InternetService       int32
# OnlineSecurity        int32
# OnlineBackup          int32
# DeviceProtection      int32
# TechSupport           int32
# StreamingTV           int32
# StreamingMovies       int32
# Contract              int32
# PaperlessBilling      int32
# PaymentMethod         int32
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                 int32
# dtype: object

# %%
#We can scale tenure, MonthlyCharges and TotalCharges from here

# %%
#We can use MinMax or StandardScaler and see which fits our ml model best

# %%
#In our case, we are using MinMaxScaler for now

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df["tenure"] = scaler.fit_transform(df[["tenure"]])

# %%
df["MonthlyCharges"] = scaler.fit_transform(df[["MonthlyCharges"]])

# %%
df["TotalCharges"] = scaler.fit_transform(df[["TotalCharges"]])

# %%
df.head(10)
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0  7590-VHVEG       0              0        1           0  0.013889
# 1  5575-GNVDE       1              0        0           0  0.472222
# 2  3668-QPYBK       1              0        0           0  0.027778
# 3  7795-CFOCW       1              0        0           0  0.625000
# 4  9237-HQITU       0              0        0           0  0.027778
# 5  9305-CDSKC       0              0        0           0  0.111111
# 6  1452-KIOVK       1              0        0           1  0.305556
# 7  6713-OKOMC       0              0        0           0  0.138889
# 8  7892-POOKP       0              0        1           0  0.388889
# 9  6388-TABGU       1              0        0           1  0.861111
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              1                0               0  ...
# 1             1              0                0               2  ...
# ...

# %%
df.to_csv("processed_churn.csv")
